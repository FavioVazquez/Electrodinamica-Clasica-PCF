# %%
from IPython.display import display, Math, Latex
from __future__ import print_function
import matplotlib.patches as mpatches
import numpy as np
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt
from numpy import *
from pylab import *

from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

#LaTeX
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# %%
r = np.linspace(1,3,100)
r1 = np.linspace(0.01,1,100)
a = 1
E1 = 1/(r**2)
E2 = 1/(r1*a)
E3 = 0.038*r**3/(a**5) - 0.03
E4 = r1
x = [0,1,1,1] 
y = [0,0,1,1]
plt.plot(r,E1)
plt.plot(r1,E4)
plt.plot(r1,E2)
plt.plot(r1,E3)
plt.plot(x, y, drawstyle='steps',color="blue")

#style
plt.xticks([])
plt.yticks([])
plt.ylim(0,2)
plt.ylabel(r'$E$', fontsize=30)
plt.xlabel(r'$r$',fontsize=30)

#Text
plt.text(0.8,1.3, r"$\textbf{(c) n=-2}$", bbox=dict(facecolor='white', alpha=0.0),fontsize=16)
plt.text(0.54,0.2, r"$\textbf{(c) n=2}$", bbox=dict(facecolor='white', alpha=0.0),fontsize=16)
plt.text(0.4,0.6, r"$\textbf{(b)}$", bbox=dict(facecolor='white', alpha=0.0),fontsize=16)
plt.text(1.04,0.4, r"$\textbf{(a)}$", bbox=dict(facecolor='white', alpha=0.0),fontsize=16)
plt.text(0.96,-0.08, r"$a$", bbox=dict(facecolor='white', alpha=0.0),fontsize=16)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
